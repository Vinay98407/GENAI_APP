# %%
print("hello vinay")
# Out:
# hello vinay

# %%
print("hi vinay you are great")
# Out:
# hi vinay you are great

# %%
print("i am to good with Gen AI")
# Out:
# i am to good with Gen AI

# %%
print("why are you asking again and again")
# Out:
# why are you asking again and again

# %%
print("hello vinay")
# Out:
# hello vinay
